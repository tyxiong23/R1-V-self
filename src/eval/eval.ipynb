# %%
from PIL import Image

import json
import os
# from matplotlib 


json_result = json.load(open('/home/tixiong/storage/xty-workspace/multimodal-reasoning/R1-V/outputs/training_v1_base/Clevr_CoGenT_TrainA_70K_Complex/Qwen2-VL-2B_Clevr_CoGenT_TrainA_70K_Complex_maxlen1024_numgen8_epoch2/eval/eval_superclevr/checkpoint-100/result.json'))

results = json_result['results']

# for idx, data in enumerate(results):
#     if data['ground_truth'] < 6:
#         continue
#     print(idx)
    
#     break

idx = 2
print(idx)
    
data = results[idx]

print('[question]:', data['question']['question'])
print('[ground_truth]:', data['ground_truth'])
print('[model_pred]:', data['model_output'])
Image.open(data['question']['image_path'])
# Out:
# 4
# [question]: How many different items are there in the image?
# [ground_truth]: 3
# [model_pred]: <think>
# There are 3 different items in the image: a yellow car, a blue SUV, and a gray motorcycle.
# </think>
#
# <answer> 3 </answer>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
